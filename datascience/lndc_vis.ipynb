# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#      Area  Perimeter  Radius    Label
# 0  1001.0     122.80   17.99  Stage 2
# 1  1326.0     132.90   20.57  Stage 2
# 2  1203.0     130.00   19.69  Stage 1
# 3   386.1      77.58   11.42  Stage 2
# 4  1297.0     135.10   20.29  Stage 2

# %%
data.count()
# Out:
# Area         569
# Perimeter    569
# Radius       569
# Label        569
# dtype: int64

# %%
plt.subplot(2,2,1)
plt.plot(data['Area'])
plt.subplot(2,2,2)
plt.plot(data['Radius'])
plt.subplot(2,2,3)
plt.plot(data['Perimeter'])

# %%
pd.scatter_matrix(data, diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AF06128>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B922668>]], dtype=object)
